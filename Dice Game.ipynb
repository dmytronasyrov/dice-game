# %%
def count_wins(dice1, dice2):
    num_dice1 = len(dice1)
    num_dice2 = len(dice2)
    
    assert num_dice1 == 6 and num_dice2 == 6
    dice1_wins, dice2_wins = 0, 0
    
    for i in range(num_dice1 * num_dice2):
        idx1 = i // num_dice1
        idx2 = i % num_dice2
        val1 = dice1[idx1]
        val2 = dice2[idx2]

        if val1 > val2:
            dice1_wins += 1
        elif val2 > val1:
            dice2_wins += 1

    return (dice1_wins, dice2_wins)

dice1 = [1, 2, 3, 4, 5, 6]
dice2 = [1, 2, 3, 4, 5, 6]
result = count_wins(dice1, dice2)
print("Win 1:", result[0], ", Win 2:", result[1])
assert result == (15, 15)

dice1 = [1, 1, 6, 6, 8, 8]
dice2 = [2, 2, 4, 4, 9, 9]
result = count_wins(dice1, dice2)
print("Win 1:", result[0], ", Win 2:", result[1])
assert result == (16, 20)
# Out:
# Win 1: 15 , Win 2: 15
# Win 1: 16 , Win 2: 20

# %%
from itertools import combinations

def count_wins(dice1, dice2):
    num_dice1 = len(dice1)
    num_dice2 = len(dice2)
    
    assert num_dice1 == 6 and num_dice2 == 6
    dice1_wins, dice2_wins = 0, 0
    
    for i in range(num_dice1 * num_dice2):
        idx1 = i // num_dice1
        idx2 = i % num_dice2
        val1 = dice1[idx1]
        val2 = dice2[idx2]

        if val1 > val2:
            dice1_wins += 1
        elif val1 < val2:
            dice2_wins += 1

    return (dice1_wins, dice2_wins)

def find_the_best_dice(dices):
    assert(all(len(dice) == 6 for dice in dices))
    print("----------------------------------")
    wins_num = [0] * len(dices)
    print(dices)
    for (dice1, dice2) in combinations(dices, 2):
        win1, win2 = count_wins(dice1, dice2)
        print(dice1, dice2, win1, win2)
        if win1 > win2:
            idx = dices.index(dice1)
        elif win2 > win1:
            idx = dices.index(dice2)
        else:
            idx = None
            
        if idx is not None:
            wins_num[idx] = wins_num[idx] + 1
            
    max_idxs = [i for i, x in enumerate(wins_num) if x == max(wins_num)]

    if len(max_idxs) == 1:
        return max_idxs[0]
    else:
        return -1

dices = [[1, 1, 6, 6, 8, 8], [2, 2, 4, 4, 9, 9], [3, 3, 5, 5, 7, 7]]
result = find_the_best_dice(dices)
print("Result 1:", result)
assert result == -1

dices = [[1, 1, 2, 4, 5, 7], [1, 2, 2, 3, 4, 7], [1, 2, 3, 4, 5, 6]]
result = find_the_best_dice(dices)
print("Result 2:", result)
assert result == 2

dices = [[1, 2, 3, 4, 5, 6], [1, 1, 2, 4, 5, 7], [1, 2, 2, 3, 4, 7]]
result = find_the_best_dice(dices)
print("Result 3:", result)
assert result == 0
# Out:
# ----------------------------------
# [[1, 1, 6, 6, 8, 8], [2, 2, 4, 4, 9, 9], [3, 3, 5, 5, 7, 7]]
# [1, 1, 6, 6, 8, 8] [2, 2, 4, 4, 9, 9] 16 20
# [1, 1, 6, 6, 8, 8] [3, 3, 5, 5, 7, 7] 20 16
# [2, 2, 4, 4, 9, 9] [3, 3, 5, 5, 7, 7] 16 20
# Result 1: -1
# ----------------------------------
# [[1, 1, 2, 4, 5, 7], [1, 2, 2, 3, 4, 7], [1, 2, 3, 4, 5, 6]]
# [1, 1, 2, 4, 5, 7] [1, 2, 2, 3, 4, 7] 15 15
# [1, 1, 2, 4, 5, 7] [1, 2, 3, 4, 5, 6] 14 17
# [1, 2, 2, 3, 4, 7] [1, 2, 3, 4, 5, 6] 13 18
# Result 2: 2
# ----------------------------------
# [[1, 2, 3, 4, 5, 6], [1, 1, 2, 4, 5, 7], [1, 2, 2, 3, 4, 7]]
# [1, 2, 3, 4, 5, 6] [1, 1, 2, 4, 5, 7] 17 14
# [1, 2, 3, 4, 5, 6] [1, 2, 2, 3, 4, 7] 18 13
# [1, 1, 2, 4, 5, 7] [1, 2, 2, 3, 4, 7] 15 15
# Result 3: 0

# %%
from itertools import combinations

def count_wins(dice1, dice2):
    num_dice1 = len(dice1)
    num_dice2 = len(dice2)
    
    assert num_dice1 == 6 and num_dice2 == 6
    dice1_wins, dice2_wins = 0, 0
    
    for i in range(num_dice1 * num_dice2):
        idx1 = i // num_dice1
        idx2 = i % num_dice2
        val1 = dice1[idx1]
        val2 = dice2[idx2]

        if val1 > val2:
            dice1_wins += 1
        elif val1 < val2:
            dice2_wins += 1

    return (dice1_wins, dice2_wins)

def find_the_best_dice(dices):
    assert(all(len(dice) == 6 for dice in dices))
    
    wins_num = [0] * len(dices)
    
    for (dice1, dice2) in combinations(dices, 2):
        win1, win2 = count_wins(dice1, dice2)
        
        if win1 > win2:
            idx = dices.index(dice1)
        elif win2 > win1:
            idx = dices.index(dice2)
        else:
            idx = None
            
        if idx is not None:
            wins_num[idx] = wins_num[idx] + 1
            
    max_idxs = [i for i, x in enumerate(wins_num) if x == max(wins_num)]

    if len(max_idxs) == 1:
        return max_idxs[0]
    else:
        return -1
    
def compute_strategy(dices):
    assert(all(len(dice) == 6 for dice in dices))
    print("---------------------------------")
    print(dices)

    strategy = dict()
    strategy["choose_first"] = False
    
    for (dice1, dice2) in combinations(dices, 2):    
        win1, win2 = count_wins(dice1, dice2)
        idx1 = dices.index(dice1)
        idx2 = dices.index(dice2)
        
        if idx1 not in strategy and win1 > win2:
            strategy[idx1] = idx2
        
        if idx2 not in strategy and win1 < win2:
            strategy[idx2] = idx1
                
        print(dice1, dice2, "Wins:", win1, win2, "Idxs", idx1, idx2)

    return strategy

dices = [[1, 1, 6, 6, 8, 8], [2, 2, 4, 4, 9, 9], [3, 3, 5, 5, 7, 7]]
result = compute_strategy(dices)
print("Result 1:", result)

dices = [[4, 4, 4, 4, 0, 0], [3, 3, 3, 3, 3, 3], [6, 6, 2, 2, 2, 2], [5, 5, 5, 1, 1, 1]]
result = compute_strategy(dices)
print("Result 2:", result)
# Out:
# ---------------------------------
# [[1, 1, 6, 6, 8, 8], [2, 2, 4, 4, 9, 9], [3, 3, 5, 5, 7, 7]]
# [1, 1, 6, 6, 8, 8] [2, 2, 4, 4, 9, 9] Wins: 16 20 Idxs 0 1
# [1, 1, 6, 6, 8, 8] [3, 3, 5, 5, 7, 7] Wins: 20 16 Idxs 0 2
# [2, 2, 4, 4, 9, 9] [3, 3, 5, 5, 7, 7] Wins: 16 20 Idxs 1 2
# Result 1: {0: 2, 1: 0, 2: 1, 'choose_first': False}
# ---------------------------------
# [[4, 4, 4, 4, 0, 0], [3, 3, 3, 3, 3, 3], [6, 6, 2, 2, 2, 2], [5, 5, 5, 1, 1, 1]]
# [4, 4, 4, 4, 0, 0] [3, 3, 3, 3, 3, 3] Wins: 24 12 Idxs 0 1
# [4, 4, 4, 4, 0, 0] [6, 6, 2, 2, 2, 2] Wins: 16 20 Idxs 0 2
# [4, 4, 4, 4, 0, 0] [5, 5, 5, 1, 1, 1] Wins: 12 24 Idxs 0 3
# [3, 3, 3, 3, 3, 3] [6, 6, 2, 2, 2, 2] Wins: 24 12 Idxs 1 2
# [3, 3, 3, 3, 3, 3] [5, 5, 5, 1, 1, 1] Wins: 18 18 Idxs 1 3
# [6, 6, 2, 2, 2, 2] [5, 5, 5, 1, 1, 1] Wins: 24 12 Idxs 2 3
# Result 2: {0: 1, 1: 2, 2: 0, 3: 0, 'choose_first': False}
